# %% [markdown]
# # Project Details :

# %% [markdown]
# ![Image%20for%20House%20Price%20Prediction.jpg](attachment:Image%20for%20House%20Price%20Prediction.jpg)

# %% [markdown]
# #### Goal:- The main aim of this project is to predict the house price based on Various Features which we are going through.

# %% [markdown]
# #### Dataset to download from below link

# %% [markdown]
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %% [markdown]
# ## Content of Projcets :

# %% [markdown]
# 1. Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
# 5. Model Deployment

# %% [markdown]
# ### 1. Data Analysis

# %%
# Load all the necessery libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

## To display all the columns of the dataframe we would have to set

pd.set_option('display.max_columns', None)

# %%
# Load the dataset

dataset = pd.read_csv('train.csv')

## Print shape of the datasets

print(dataset.shape)
# Out:
# (1460, 81)

# %%
# Print the top5 records

dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### 1 Data Analysis

# %% [markdown]
#     1a. Missing Values
#     1b. All the numerical Variables
#     1c. Distribution of the Numerical Variables
#     1d. Categorical Variables
#     1e. Cardinality of categorical Variables
#     1f. Outliers
#     1g. Relation between Independent and dependent Variables

# %% [markdown]
# #### 1a. Missing Values

# %%
# Here we will check the percentage of nan values present in each feature
# 1 -step make the list of features which has missing values

features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>1]

# 2- step print the feature name and the percentage of missing values

for features in features_with_na:
    print(features, np.round(dataset[features].isnull().mean(),4), '% missing Values')
# Out:
# LotFrontage 0.1774 % missing Values
# Alley 0.9377 % missing Values
# MasVnrType 0.0055 % missing Values
# MasVnrArea 0.0055 % missing Values
# BsmtQual 0.0253 % missing Values
# BsmtCond 0.0253 % missing Values
# BsmtExposure 0.026 % missing Values
# BsmtFinType1 0.0253 % missing Values
# BsmtFinType2 0.026 % missing Values
# FireplaceQu 0.4726 % missing Values
# GarageType 0.0555 % missing Values
# GarageYrBlt 0.0555 % missing Values
# GarageFinish 0.0555 % missing Values
# GarageQual 0.0555 % missing Values
# GarageCond 0.0555 % missing Values
# PoolQC 0.9952 % missing Values
# Fence 0.8075 % missing Values
# MiscFeature 0.963 % missing Values

# %% [markdown]
# ### Since they are many missing values, we need to find the relationship between missing values and Sales Price
# Let's plot some diagram for this relationship

# %%
for feature in features_with_na:
    data = dataset.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    # let's calculate the mean SalePrice where the information is missing or present

    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# Here with the relation between the missing values with SalesPrice is clearly vissible. So we need to replace these non values with something meaningful which we will do in the feature engineering section.

# %% [markdown]
# From the above dataset some of the features like Id is not required

# %%
print("Id of houses {}".format(len(dataset['Id'])) )
# Out:
# Id of houses 1460

# %% [markdown]
# #### 1b. All the numerical Variables

# %%
# List of all numerical values

numerical_features = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']

print("Number of numerical variables {}".format(len(numerical_features)))

# visualise the numerical variables

dataset[numerical_features].head()
# Out:
# Number of numerical variables 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# #### Temporal Variables(Eg: Datetime Variables)
#
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years or no of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold. We will be performing this analysis in the Feature Engineering.

# %%
year_feature = [feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables

for feature in year_feature:
    print(feature, dataset[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# Lets analyze the Temporal Datetime Variables
# We will check whether there is a relation between year the house is sold and the sales price

plt.figure(figsize=(10,6))
dataset.groupby("YrSold")["SalePrice"].median().plot()
plt.xlabel("Year Sold")
plt.ylabel("Sale Price")
plt.title("House Price vs Year Sold")
plt.show()

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# Here we will compare the difference between All years feature with SalePrice

for feature in year_feature:
    if feature != "YrSold":
        data = dataset.copy()
        
        plt.figure(figsize=(10,6))
        data[feature] = data["YrSold"] - data[feature]
        plt.scatter(data[feature], data["SalePrice"])
        plt.title(feature)
        plt.xlabel(feature)
        plt.ylabel("Sale Price")
        plt.show()

# %%
# Numerical variables are usually of 2 type
# 1. Continous variable and Discrete Variables

discrete_feature = [feature for feature in numerical_features if len(data[feature].unique())<25 and feature not in year_feature + ['id']]
print("Descrete variables count {}".format(len(discrete_feature)))
# Out:
# Descrete variables count 17

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
# Lets Find the realtionship between them and Sale PRice
for feature in discrete_feature:
    data = dataset.copy()
    data.groupby(feature)["SalePrice"].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
# There is a relationship between variable number and SalePrice

# %%
# Continuous Variable

continuous_feature = [feature for feature in numerical_features if feature not in discrete_feature + year_feature + ["Id"]]
print("Number of Continuous Feature {}".format(len(continuous_feature)))
# Out:
# Number of Continuous Feature 16

# %%
continuous_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
### Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data = dataset.copy()
    data[feature].hist(bins = 25)
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel("Counts")
    plt.show()

# %%
## We will be using logarithmic transformation for 

for feature in continuous_feature:
    data = dataset.copy()
    if 0 in data[feature].unique():  # As Log(0) is undefiened so we filter out the feature those who doesnot contain 0.
        pass
    else:
        data[feature] = np.log(data[feature])
        data['SalePrice'] = np.log(data["SalePrice"])
        plt.scatter(data[feature],data['SalePrice'])
        plt.title(feature)
        plt.xlabel(feature)
        plt.ylabel("Sale Price")
        plt.show()

# %% [markdown]
# #### 1f. Outliers

# %%
for feature in continuous_feature:
    data = dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column = feature)
        plt.title(feature)
        plt.xlabel(feature)
        plt.ylabel(feature)
        plt.show()

# %% [markdown]
# #### 1d. Categorical Variables

# %%
categorical_features = [feature for feature in dataset.columns if data[feature].dtypes == 'O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(categorical_features)
# Out:
# 43

# %%
data[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_features:
    print("The feature is {} and No of catergories are {}".format(feature, len(dataset[feature].unique())))
# Out:
# The feature is MSZoning and No of catergories are 5
# The feature is Street and No of catergories are 2
# The feature is Alley and No of catergories are 3
# The feature is LotShape and No of catergories are 4
# The feature is LandContour and No of catergories are 4
# The feature is Utilities and No of catergories are 2
# The feature is LotConfig and No of catergories are 5
# The feature is LandSlope and No of catergories are 3
# The feature is Neighborhood and No of catergories are 25
# The feature is Condition1 and No of catergories are 9
# The feature is Condition2 and No of catergories are 8
# The feature is BldgType and No of catergories are 5
# The feature is HouseStyle and No of catergories are 8
# The feature is RoofStyle and No of catergories are 6
# The feature is RoofMatl and No of catergories are 8
# The feature is Exterior1st and No of catergories are 15
# The feature is Exterior2nd and No of catergories are 16
# The feature is MasVnrType and No of catergories are 5
# ...

# %% [markdown]
# #### 1g. Relation between Independen and dependent Variables

# %%
# Find out the relationship between categorical variable and dependent feature SalesPrice

# %%
for feature in categorical_features:
    data=dataset.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()
